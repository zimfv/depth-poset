# %%
import numpy as np
from scipy.optimize import minimize
from scipy.spatial import Delaunay, delaunay_plot_2d

from matplotlib import pyplot as plt


import cvxpy as cp

# %%
def target(points, edges):
    # 
    return np.var(np.linalg.norm(points[edges[:, 0]] - points[edges[:, 1]], axis=1))

# %%
n = 8

points = np.random.random([n, 2])
tri = Delaunay(points)

edges = np.unique(np.sort(np.concatenate([tri.simplices[:, [0, 1]], 
                                          tri.simplices[:, [0, 2]], 
                                          tri.simplices[:, [1, 2]], ]), axis=1), axis=0)


plt.scatter(points[:, 0], points[:, 1], )
for edge in edges:
    plt.plot(points[edge, 0], points[edge, 1], )

# %%
# Define optimization variables
opt_points = cp.Variable([n, 2])
opt_points.value = points

# Define the target function in cvxpy
edge_lengths = cp.norm(opt_points[edges[:, 0]] - opt_points[edges[:, 1]], axis=1, p=2)
mean_length = cp.sum(edge_lengths) / len(edges)
squared_deviation = cp.sum_squares(edge_lengths - mean_length)


# Objective to minimize the sum of squared deviations
objective = cp.Minimize(squared_deviation)


# Define constraints to ensure all points are on the same side of each edge
constraints = []
for edge in edges:
    p1, p2 = points[edge]
    a, b = p2[1] - p1[1], p1[0] - p2[0]
    c = -a * p1[0] - b * p1[1]
    # Compute linear equation for all points
    signs = a * opt_points[:, 0] + b * opt_points[:, 1] + c
    # Ensure all signs are either non-negative or non-positive
    constraints.append(signs >= 0)
    constraints.append(signs <= 0)
    
for i in range(n):
    constraints.append(opt_points[i, 0] >= 0)
    constraints.append(opt_points[i, 0] <= 1)
    constraints.append(opt_points[i, 1] >= 0)
    constraints.append(opt_points[i, 1] <= 1)

# Solve the optimization problem
problem = cp.Problem(objective, constraints)
problem.solve()

# Extract optimized points
optimized_points = opt_points.value



print(f'f_old = {target(points, edges):.4f}')
print(f'f_new = {target(optimized_points, edges):.4f}')

fig, axs = plt.subplots(1, 2, figsize=(11, 5))
axs[0].scatter(points[:, 0], points[:, 1], )
for edge in edges:
    axs[0].plot(points[edge, 0], points[edge, 1], )

axs[1].scatter(optimized_points[:, 0], optimized_points[:, 1], )
for edge in edges:
    axs[1].plot(optimized_points[edge, 0], optimized_points[edge, 1], )

plt.show()
# Out:
# ---------------------------------------------------------------------------
# DCPError                                  Traceback (most recent call last)
# Cell In[29], line 35
#      33 # Solve the optimization problem
#      34 problem = cp.Problem(objective, constraints)
# ---> 35 problem.solve()
#      37 # Extract optimized points
#      38 optimized_points = opt_points.value
#
# File ~/Jupyter/jupyter-env/lib/python3.12/site-packages/cvxpy/problems/problem.py:577, in Problem.solve(self, *args, **kwargs)
#     574         raise ValueError(
#     575             "Cannot specify both 'solver' and 'solver_path'. Please choose one.")
#     576     return self._solve_solver_path(solve_func,solver_path, args, kwargs)
# --> 577 return solve_func(self, *args, **kwargs)
#
# File ~/Jupyter/jupyter-env/lib/python3.12/site-packages/cvxpy/problems/problem.py:1147, in Problem._solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, canon_backend, **kwargs)
#    1144         self.unpack(chain.retrieve(soln))
#    1145         return self.value
# -> 1147 data, solving_chain, inverse_data = self.get_problem_data(
#    1148     solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, kwargs
#    1149 )
#    1151 if verbose:
#    1152     print(_NUM_SOLVER_STR)
#
# File ~/Jupyter/jupyter-env/lib/python3.12/site-packages/cvxpy/problems/problem.py:720, in Problem.get_problem_data(self, solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, solver_opts)
#     718 if key != self._cache.key:
#     719     self._cache.invalidate()
# --> 720     solving_chain = self._construct_chain(
#     721         solver=solver, gp=gp,
#     722         enforce_dpp=enforce_dpp,
#     723         ignore_dpp=ignore_dpp,
#     724         canon_backend=canon_backend,
#     725         solver_opts=solver_opts)
#     726     self._cache.key = key
#     727     self._cache.solving_chain = solving_chain
#
# File ~/Jupyter/jupyter-env/lib/python3.12/site-packages/cvxpy/problems/problem.py:971, in Problem._construct_chain(self, solver, gp, enforce_dpp, ignore_dpp, canon_backend, solver_opts)
#     969 candidate_solvers = self._find_candidate_solvers(solver=solver, gp=gp)
#     970 self._sort_candidate_solvers(candidate_solvers)
# --> 971 return construct_solving_chain(self, candidate_solvers, gp=gp,
#     972                                enforce_dpp=enforce_dpp,
#     973                                ignore_dpp=ignore_dpp,
#     974                                canon_backend=canon_backend,
#     975                                solver_opts=solver_opts,
#     976                                specified_solver=solver)
#
# File ~/Jupyter/jupyter-env/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain.py:236, in construct_solving_chain(problem, candidates, gp, enforce_dpp, ignore_dpp, canon_backend, solver_opts, specified_solver)
#     234 if len(problem.variables()) == 0:
#     235     return SolvingChain(reductions=[ConstantSolver()])
# --> 236 reductions = _reductions_for_problem_class(problem, candidates, gp, solver_opts)
#     238 # Process DPP status of the problem.
#     239 dpp_context = 'dcp' if not gp else 'dgp'
#
# File ~/Jupyter/jupyter-env/lib/python3.12/site-packages/cvxpy/reductions/solvers/solving_chain.py:150, in _reductions_for_problem_class(problem, candidates, gp, solver_opts)
#     147     elif problem.is_dqcp():
#     148         append += ("\nHowever, the problem does follow DQCP rules. "
#     149                    "Consider calling solve() with `qcp=True`.")
# --> 150     raise DCPError(
#     151         "Problem does not follow DCP rules. Specifically:\n" + append)
#     152 elif gp and not problem.is_dgp():
#     153     append = build_non_disciplined_error_msg(problem, 'DGP')
#
# DCPError: Problem does not follow DCP rules. Specifically:
# The objective is not DCP. Its following subexpressions are not:
# Pnorm(var535[0, 0, 0, 0, 0, 1, 1, 1, 1, 2, 3, 3, 3, 3, 4, 6] + -var535[2, 3, 4, 5, 7, 2, 3, 4, 6, 4, 4, 5, 6, 7, 5, 7], 2) + Promote(-Sum(Pnorm(var535[0, 0, 0, 0, 0, 1, 1, 1, 1, 2, 3, 3, 3, 3, 4, 6] + -var535[2, 3, 4, 5, 7, 2, 3, 4, 6, 4, 4, 5, 6, 7, 5, 7], 2), None, False) / 16.0, (16,))
